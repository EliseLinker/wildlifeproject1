# %%
import os
import csv
import pandas as pd

# Dependencies for Weather
import requests as req
import openweathermapy.core as owm
from citipy import citipy

#Dependencies for random coordinates
import random
from random import uniform

#Dependencies for Df and Analysis
import numpy as np

#Dependencies for Plots
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
#Dependencies for api key
from config import api_key


InputFile = 'CITES_Results1617_JRE.csv'
ImporterFile = 'Top10ImpByTrans_EML.csv'
ExporterFile = 'Top10ExpByTrans_EML.csv'
OriginFile = 'Top10OriginByTrans_EML.csv'
ImpQtyFile = 'Top10ImpByQuantity_EML.csv'
ExpQtyFile = 'Top10ExpByQuantity_EML.csv'
LatLonFile = 'country_lat_lon.xlsx'

# %%
csvpath = os.path.join(InputFile)
input_df = pd.read_csv(csvpath)
print(input_df.columns.get_values())
input_df.head(1)
# Out:
# ['Year' 'App.' 'Taxon' 'Class' 'Order' 'Family' 'Genus' 'Importer'
#  'Exporter' 'Origin' 'Importer reported quantity'
#  'Exporter reported quantity' 'Term' 'Unit' 'Purpose' 'Source'
#  'Purpose Description' 'Source Description' 'Importer Country Name'
#  'Exporter Country Name']
#    Year App.           Taxon Class          Order        Family   Genus  \
# 0  2016    I  Aquila heliaca  Aves  Falconiformes  Accipitridae  Aquila
#
#   Importer Exporter Origin  Importer reported quantity  \
# 0       TR       NL     CZ                         NaN
#
#    Exporter reported quantity    Term Unit Purpose Source Purpose Description  \
# 0                         1.0  bodies  NaN       T      C          Commercial
#
#                                   Source Description Importer Country Name  \
# 0  Animals bred in captivity in accordance with R...                Turkey
#
#   Exporter Country Name
# 0           Netherlands

# %%
latlonfile_df = pd.read_excel(LatLonFile)
latlonfile_df.head(1)
# Out:
#   Country  Lattitude  Longitude     Name
# 0      AD  42.546245   1.601554  Andorra

# %%
print(input_df.loc[input_df["Class"]=="Reptilia"])
TopImporter_croc_df = pd.DataFrame(input_df.loc[input_df["Class"]=="Reptilia"])
# Out:
#        Year App.                             Taxon     Class       Order  \
# 3      2016   II                 Caiman crocodilus  Reptilia  Crocodylia
# 4      2016   II          Caiman crocodilus fuscus  Reptilia  Crocodylia
# 5      2016   II              Crocodylus niloticus  Reptilia  Crocodylia
# 7      2016   II                 Python bivittatus  Reptilia   Serpentes
# 8      2016   II                 Python bivittatus  Reptilia   Serpentes
# 10     2016    I              Crocodylus niloticus  Reptilia  Crocodylia
# 11     2016   II        Alligator mississippiensis  Reptilia  Crocodylia
# 12     2016   II              Crocodylus niloticus  Reptilia  Crocodylia
# 13     2016   II                Python brongersmai  Reptilia   Serpentes
# 14     2016   II                Python reticulatus  Reptilia   Serpentes
# 15     2016   II                 Salvator merianae  Reptilia      Sauria
# 16     2016   II                  Varanus salvator  Reptilia      Sauria
# 17     2016   II                  Varanus salvator  Reptilia      Sauria
# 18     2016   II                  Eunectes notaeus  Reptilia   Serpentes
# 19     2016   II              Crocodylus niloticus  Reptilia  Crocodylia
# 24     2016   II      Caiman crocodilus crocodilus  Reptilia  Crocodylia
# 25     2016   II          Caiman crocodilus fuscus  Reptilia  Crocodylia
# 26     2016   II              Crocodylus niloticus  Reptilia  Crocodylia
# 27     2016   II              Crocodylus niloticus  Reptilia  Crocodylia
# 28     2016   II                Crocodylus porosus  Reptilia  Crocodylia
# 29     2016   II                Crocodylus porosus  Reptilia  Crocodylia
# 30     2016   II                 Python bivittatus  Reptilia   Serpentes
# 31     2016   II              Python breitensteini  Reptilia   Serpentes
# 32     2016   II                     Python regius  Reptilia   Serpentes
# 33     2016   II                Python reticulatus  Reptilia   Serpentes
# 34     2016   II                Python reticulatus  Reptilia   Serpentes
# 59     2016   II        Alligator mississippiensis  Reptilia  Crocodylia
# 60     2016   II      Caiman crocodilus crocodilus  Reptilia  Crocodylia
# 67     2016   II              Python breitensteini  Reptilia   Serpentes
# 68     2016   II                Python brongersmai  Reptilia   Serpentes
# ...     ...  ...                               ...       ...         ...
# 60502  2016   II               Trioceros cristatus  Reptilia      Sauria
# 60503  2016   II                 Trioceros montium  Reptilia      Sauria
# 60504  2016   II            Trioceros quadricornis  Reptilia      Sauria
# 60510  2016   II        Alligator mississippiensis  Reptilia  Crocodylia
# 60526  2016    I                  Cheloniidae spp.  Reptilia  Testudines
# 60539  2016    I  Eretmochelys imbricata imbricata  Reptilia  Testudines
# 60543  2016   II            Gongylophis colubrinus  Reptilia   Serpentes
# 60544  2016   II               Chamaeleo africanus  Reptilia      Sauria
# 60559  2016   II              Crocodylus niloticus  Reptilia  Crocodylia
# 60563  2016   II                 Varanus niloticus  Reptilia      Sauria
# 60565  2016   II        Alligator mississippiensis  Reptilia  Crocodylia
# 60566  2016   II        Alligator mississippiensis  Reptilia  Crocodylia
# 60567  2016   II        Alligator mississippiensis  Reptilia  Crocodylia
# 60568  2016   II                 Varanus niloticus  Reptilia      Sauria
# 60569  2016   II                       Python spp.  Reptilia   Serpentes
# 60578  2016   II                  Testudo hermanni  Reptilia  Testudines
# 60579  2016   II                  Testudo hermanni  Reptilia  Testudines
# 60589  2016    I                   Caretta caretta  Reptilia  Testudines
# 60592  2016    I               Astrochelys radiata  Reptilia  Testudines
# 60594  2016    I               Astrochelys radiata  Reptilia  Testudines
# 60602  2016    I             Lepidochelys olivacea  Reptilia  Testudines
# 60603  2016   II               Trioceros cristatus  Reptilia      Sauria
# 60604  2016   II                 Trioceros montium  Reptilia      Sauria
# 60605  2016   II            Trioceros quadricornis  Reptilia      Sauria
# 60606  2016   II            Trioceros wiedersheimi  Reptilia      Sauria
# 60613  2016   II        Alligator mississippiensis  Reptilia  Crocodylia
# 60614  2016   II        Alligator mississippiensis  Reptilia  Crocodylia
# 60624  2016    I                    Chelonia mydas  Reptilia  Testudines
# 60625  2016    I            Eretmochelys imbricata  Reptilia  Testudines
# 60626  2016    I             Lepidochelys olivacea  Reptilia  Testudines
#
#                Family         Genus Importer Exporter Origin  \
# 3       Alligatoridae        Caiman       TR       NL     CO
# 4       Alligatoridae        Caiman       TR       NL     CO
# 5        Crocodylidae    Crocodylus       TR       NL     ZA
# 7          Pythonidae        Python       TR       NL     VN
# 8          Pythonidae        Python       TR       NL    NaN
# 10       Crocodylidae    Crocodylus       TR       NL     ZW
# 11      Alligatoridae     Alligator       TR       NL     US
# 12       Crocodylidae    Crocodylus       TR       NL     ZW
# 13         Pythonidae        Python       TR       NL     ID
# 14         Pythonidae        Python       TR       NL     ID
# 15            Teiidae      Salvator       TR       NL     AR
# 16          Varanidae       Varanus       TR       NL     ID
# 17          Varanidae       Varanus       TR       NL     MY
# 18             Boidae      Eunectes       TR       NL    NaN
# 19       Crocodylidae    Crocodylus       TR       NL     ZW
# 24      Alligatoridae        Caiman       CH       NL     CO
# 25      Alligatoridae        Caiman       CH       NL     CO
# 26       Crocodylidae    Crocodylus       CH       NL     MG
# 27       Crocodylidae    Crocodylus       CH       NL     ZW
# 28       Crocodylidae    Crocodylus       CH       NL     AU
# 29       Crocodylidae    Crocodylus       CH       NL     PG
# 30         Pythonidae        Python       CH       NL     VN
# 31         Pythonidae        Python       CH       NL     MY
# 32         Pythonidae        Python       CH       NL    NaN
# 33         Pythonidae        Python       CH       NL     LA
# 34         Pythonidae        Python       CH       NL     VN
# 59      Alligatoridae     Alligator       CH       NL     US
# 60      Alligatoridae        Caiman       CH       NL     GY
# 67         Pythonidae        Python       CH       NL     MY
# 68         Pythonidae        Python       CH       NL     ID
# ...               ...           ...      ...      ...    ...
# 60502  Chamaeleonidae     Trioceros       US       GQ    NaN
# 60503  Chamaeleonidae     Trioceros       US       GQ    NaN
# 60504  Chamaeleonidae     Trioceros       US       GQ    NaN
# 60510   Alligatoridae     Alligator       US       AG     US
# 60526     Cheloniidae           NaN       US       LC    NaN
# 60539     Cheloniidae  Eretmochelys       US       GD    NaN
# 60543          Boidae   Gongylophis       US       ER    NaN
# 60544  Chamaeleonidae     Chamaeleo       US       ER    NaN
# 60559    Crocodylidae    Crocodylus       US       YE     ZW
# 60563       Varanidae       Varanus       FR       TD    NaN
# 60565   Alligatoridae     Alligator       US       BL     US
# 60566   Alligatoridae     Alligator       US       BL     US
# 60567   Alligatoridae     Alligator       FR       BL     US
# 60568       Varanidae       Varanus       FR       BL     TD
# 60569      Pythonidae        Python       US       GP    NaN
# 60578    Testudinidae       Testudo       GB       GG     GB
# 60579    Testudinidae       Testudo       GB       GG    NaN
# 60589     Cheloniidae       Caretta       ES       GG    NaN
# 60592    Testudinidae   Astrochelys       JE       GG     MG
# 60594    Testudinidae   Astrochelys       MG       KM     MG
# 60602     Cheloniidae  Lepidochelys       BE       MV    NaN
# 60603  Chamaeleonidae     Trioceros       JP       GN    NaN
# 60604  Chamaeleonidae     Trioceros       JP       GN    NaN
# 60605  Chamaeleonidae     Trioceros       JP       GN    NaN
# 60606  Chamaeleonidae     Trioceros       JP       GN    NaN
# 60613   Alligatoridae     Alligator       ES       GI     US
# 60614   Alligatoridae     Alligator       ES       AD     US
# 60624     Cheloniidae      Chelonia       PT       ST    NaN
# 60625     Cheloniidae  Eretmochelys       PT       ST    NaN
# 60626     Cheloniidae  Lepidochelys       PT       ST    NaN
#
#        Importer reported quantity  Exporter reported quantity  \
# 3                             1.0                         NaN
# 4                             NaN                         5.0
# 5                             1.0                         NaN
# 7                            25.0                        33.0
# 8                             1.0                         NaN
# 10                            1.0                         NaN
# 11                          479.0                       487.0
# 12                            NaN                         1.0
# 13                            9.0                        10.0
# 14                            3.0                         3.0
# 15                            2.0                         4.0
# 16                           86.0                       105.0
# 17                            6.0                         6.0
# 18                            1.0                         NaN
# 19                            1.0                         1.0
# 24                            NaN                         4.0
# 25                            NaN                        71.0
# 26                            NaN                         1.0
# 27                            NaN                         3.0
# 28                            NaN                         2.0
# 29                            NaN                         1.0
# 30                            NaN                        22.0
# 31                            NaN                         1.0
# 32                            NaN                        22.0
# 33                            NaN                         2.0
# 34                            NaN                         1.0
# 59                            NaN                      5617.0
# 60                            NaN                         1.0
# 67                            NaN                         1.0
# 68                            NaN                         8.0
# ...                           ...                         ...
# 60502                        32.0                         NaN
# 60503                        74.0                         NaN
# 60504                       228.0                         NaN
# 60510                         1.0                         NaN
# 60526                         1.0                         NaN
# 60539                         1.0                         NaN
# 60543                         2.0                         NaN
# 60544                         3.0                         NaN
# 60559                         1.0                         NaN
# 60563                      6819.0                     10219.0
# 60565                         2.0                         NaN
# 60566                         2.0                         NaN
# 60567                         8.0                         NaN
# 60568                        12.0                         NaN
# 60569                         1.0                         NaN
# 60578                         NaN                         1.0
# 60579                         NaN                         1.0
# 60589                         NaN                         1.0
# 60592                         NaN                         1.0
# 60594                       110.0                         NaN
# 60602                         4.0                         NaN
# 60603                        10.0                         NaN
# 60604                        79.0                         NaN
# 60605                        90.0                         NaN
# 60606                        48.0                         NaN
# 60613                         3.0                         NaN
# 60614                         4.0                         NaN
# 60624                       867.0                         NaN
# 60625                       223.0                         NaN
# 60626                      1629.0                         NaN
#
#                            Term Unit Purpose Source  \
# 3      leather products (small)  NaN       T      C
# 4      leather products (small)  NaN       T      C
# 5      leather products (small)  NaN       T      C
# 7      leather products (small)  NaN       T      C
# 8      leather products (small)  NaN       T      C
# 10     leather products (small)  NaN       T      W
# 11     leather products (small)  NaN       T      W
# 12     leather products (small)  NaN       T      W
# 13     leather products (small)  NaN       T      W
# 14     leather products (small)  NaN       T      W
# 15     leather products (small)  NaN       T      W
# 16     leather products (small)  NaN       T      W
# 17     leather products (small)  NaN       T      W
# 18                         live  NaN       Z      F
# 19     leather products (small)  NaN       T      R
# 24     leather products (small)  NaN       T      C
# 25     leather products (small)  NaN       T      C
# 26     leather products (small)  NaN       T      C
# 27     leather products (small)  NaN       T      C
# 28     leather products (small)  NaN       T      C
# 29     leather products (small)  NaN       T      C
# 30     leather products (small)  NaN       T      C
# 31     leather products (small)  NaN       T      C
# 32                         live  NaN       T      C
# 33     leather products (small)  NaN       T      C
# 34     leather products (small)  NaN       T      C
# 59     leather products (small)  NaN       T      W
# 60     leather products (small)  NaN       T      W
# 67     leather products (small)  NaN       T      W
# 68     leather products (small)  NaN       T      W
# ...                         ...  ...     ...    ...
# 60502                      live  NaN       T      F
# 60503                      live  NaN       T      F
# 60504                      live  NaN       T      F
# 60510  leather products (small)  NaN       T      I
# 60526                 jewellery  NaN       P      I
# 60539                 carapaces  NaN       P      I
# 60543                 specimens  NaN       S      W
# 60544                 specimens  NaN       S      W
# 60559                  trophies  NaN       H      W
# 60563                     skins  NaN       T      W
# 60565  leather products (small)  NaN       T      I
# 60566  leather products (small)  NaN       P      I
# 60567  leather products (small)  NaN       T      W
# 60568  leather products (small)  NaN       T      W
# 60569  leather products (large)  NaN       P      I
# 60578                      live  NaN       P      C
# 60579                      live  NaN       P      C
# 60589                      live  NaN       N      W
# 60592                      live  NaN       Z      O
# 60594                      live  NaN       L      I
# 60602                      live  NaN       Z      W
# 60603                      live  NaN       T      F
# 60604                      live  NaN       T      F
# 60605                      live  NaN       T      F
# 60606                      live  NaN       T      F
# 60613  leather products (small)  NaN       T      W
# 60614  leather products (small)  NaN       T      W
# 60624                 specimens  NaN       S      W
# 60625                 specimens  NaN       S      W
# 60626                 specimens  NaN       S      W
#
#                                 Purpose Description  \
# 3                                        Commercial
# 4                                        Commercial
# 5                                        Commercial
# 7                                        Commercial
# 8                                        Commercial
# 10                                       Commercial
# 11                                       Commercial
# 12                                       Commercial
# 13                                       Commercial
# 14                                       Commercial
# 15                                       Commercial
# 16                                       Commercial
# 17                                       Commercial
# 18                                              Zoo
# 19                                       Commercial
# 24                                       Commercial
# 25                                       Commercial
# 26                                       Commercial
# 27                                       Commercial
# 28                                       Commercial
# 29                                       Commercial
# 30                                       Commercial
# 31                                       Commercial
# 32                                       Commercial
# 33                                       Commercial
# 34                                       Commercial
# 59                                       Commercial
# 60                                       Commercial
# 67                                       Commercial
# 68                                       Commercial
# ...                                             ...
# 60502                                    Commercial
# 60503                                    Commercial
# 60504                                    Commercial
# 60510                                    Commercial
# 60526                                      Personal
# 60539                                      Personal
# 60543                                    Scientific
# 60544                                    Scientific
# 60559                                Hunting trophy
# 60563                                    Commercial
# 60565                                    Commercial
# 60566                                      Personal
# 60567                                    Commercial
# 60568                                    Commercial
# 60569                                      Personal
# 60578                                      Personal
# 60579                                      Personal
# 60589  Reintroduction or introduction into the wild
# 60592                                           Zoo
# 60594         Law enforcement / judicial / forensic
# 60602                                           Zoo
# 60603                                    Commercial
# 60604                                    Commercial
# 60605                                    Commercial
# 60606                                    Commercial
# 60613                                    Commercial
# 60614                                    Commercial
# 60624                                    Scientific
# 60625                                    Scientific
# 60626                                    Scientific
#
#                                       Source Description  \
# 3      Animals bred in captivity in accordance with R...
# 4      Animals bred in captivity in accordance with R...
# 5      Animals bred in captivity in accordance with R...
# 7      Animals bred in captivity in accordance with R...
# 8      Animals bred in captivity in accordance with R...
# 10                        Specimens taken from the wild.
# 11                        Specimens taken from the wild.
# 12                        Specimens taken from the wild.
# 13                        Specimens taken from the wild.
# 14                        Specimens taken from the wild.
# 15                        Specimens taken from the wild.
# 16                        Specimens taken from the wild.
# 17                        Specimens taken from the wild.
# 18     Animals born in captivity (F1 or subsequent ge...
# 19     Ranched specimens: specimens of animals reared...
# 24     Animals bred in captivity in accordance with R...
# 25     Animals bred in captivity in accordance with R...
# 26     Animals bred in captivity in accordance with R...
# 27     Animals bred in captivity in accordance with R...
# 28     Animals bred in captivity in accordance with R...
# 29     Animals bred in captivity in accordance with R...
# 30     Animals bred in captivity in accordance with R...
# 31     Animals bred in captivity in accordance with R...
# 32     Animals bred in captivity in accordance with R...
# 33     Animals bred in captivity in accordance with R...
# 34     Animals bred in captivity in accordance with R...
# 59                        Specimens taken from the wild.
# 60                        Specimens taken from the wild.
# 67                        Specimens taken from the wild.
# 68                        Specimens taken from the wild.
# ...                                                  ...
# 60502  Animals born in captivity (F1 or subsequent ge...
# 60503  Animals born in captivity (F1 or subsequent ge...
# 60504  Animals born in captivity (F1 or subsequent ge...
# 60510                    Confiscated or seized specimens
# 60526                    Confiscated or seized specimens
# 60539                    Confiscated or seized specimens
# 60543                     Specimens taken from the wild.
# 60544                     Specimens taken from the wild.
# 60559                     Specimens taken from the wild.
# 60563                     Specimens taken from the wild.
# 60565                    Confiscated or seized specimens
# 60566                    Confiscated or seized specimens
# 60567                     Specimens taken from the wild.
# 60568                     Specimens taken from the wild.
# 60569                    Confiscated or seized specimens
# 60578  Animals bred in captivity in accordance with R...
# 60579  Animals bred in captivity in accordance with R...
# 60589                     Specimens taken from the wild.
# 60592                           Pre-Convention specimens
# 60594                    Confiscated or seized specimens
# 60602                     Specimens taken from the wild.
# 60603  Animals born in captivity (F1 or subsequent ge...
# 60604  Animals born in captivity (F1 or subsequent ge...
# 60605  Animals born in captivity (F1 or subsequent ge...
# 60606  Animals born in captivity (F1 or subsequent ge...
# 60613                     Specimens taken from the wild.
# 60614                     Specimens taken from the wild.
# 60624                     Specimens taken from the wild.
# 60625                     Specimens taken from the wild.
# 60626                     Specimens taken from the wild.
#
#           Importer Country Name  Exporter Country Name
# 3                        Turkey            Netherlands
# 4                        Turkey            Netherlands
# 5                        Turkey            Netherlands
# 7                        Turkey            Netherlands
# 8                        Turkey            Netherlands
# 10                       Turkey            Netherlands
# 11                       Turkey            Netherlands
# 12                       Turkey            Netherlands
# 13                       Turkey            Netherlands
# 14                       Turkey            Netherlands
# 15                       Turkey            Netherlands
# 16                       Turkey            Netherlands
# 17                       Turkey            Netherlands
# 18                       Turkey            Netherlands
# 19                       Turkey            Netherlands
# 24                  Switzerland            Netherlands
# 25                  Switzerland            Netherlands
# 26                  Switzerland            Netherlands
# 27                  Switzerland            Netherlands
# 28                  Switzerland            Netherlands
# 29                  Switzerland            Netherlands
# 30                  Switzerland            Netherlands
# 31                  Switzerland            Netherlands
# 32                  Switzerland            Netherlands
# 33                  Switzerland            Netherlands
# 34                  Switzerland            Netherlands
# 59                  Switzerland            Netherlands
# 60                  Switzerland            Netherlands
# 67                  Switzerland            Netherlands
# 68                  Switzerland            Netherlands
# ...                         ...                    ...
# 60502  United States of America      Equatorial Guinea
# 60503  United States of America      Equatorial Guinea
# 60504  United States of America      Equatorial Guinea
# 60510  United States of America    Antigua and Barbuda
# 60526  United States of America            Saint Lucia
# 60539  United States of America                Grenada
# 60543  United States of America                Eritrea
# 60544  United States of America                Eritrea
# 60559  United States of America                  Yemen
# 60563                    France                   Chad
# 60565  United States of America       Saint-Barthélemy
# 60566  United States of America       Saint-Barthélemy
# 60567                    France       Saint-Barthélemy
# 60568                    France       Saint-Barthélemy
# 60569  United States of America             Guadeloupe
# 60578            United Kingdom               Guernsey
# 60579            United Kingdom               Guernsey
# 60589                     Spain               Guernsey
# 60592                    Jersey               Guernsey
# 60594                Madagascar                Comoros
# 60602                   Belgium               Maldives
# 60603                     Japan                 Guinea
# 60604                     Japan                 Guinea
# 60605                     Japan                 Guinea
# 60606                     Japan                 Guinea
# 60613                     Spain              Gibraltar
# 60614                     Spain                Andorra
# 60624                  Portugal  Sao Tome and Principe
# 60625                  Portugal  Sao Tome and Principe
# 60626                  Portugal  Sao Tome and Principe
#
# [17910 rows x 20 columns]

# %%
#print(TopImporter_croc_df.head())
# Group by Importing country
# Using GroupBy in order to summarize the data by 'Importer Country Name' values
#GrpdByImporterData = input_df.groupby(['Importer Country Name'])
#GrpdByImporterData = TopImporter_croc_df.groupby(['Importer Country Name'])
GrpdByImporterData = TopImporter_croc_df.groupby(['Importer'])

# Transaction count
#ImportTransactionCount = TopImporter_croc_df['Importer Country Name'].value_counts()

# Transaction count
ImportTransactionCount = TopImporter_croc_df['Importer'].value_counts()


# Construct the output table
# In order to be visualized, a data function must be used...
TopImporter_df = pd.DataFrame({'Transaction Count': ImportTransactionCount})
# convert the index into a column
TopImporter_df.sort_values("Transaction Count", inplace=True, ascending=False)
TopImporter_df.reset_index(inplace=True)
TopImporter_df = TopImporter_df.rename(columns = {'index' : 'Import Country'})
TopImporter_df.to_csv(ImporterFile, encoding='utf-8', index=False)
TopImporter_df.head(10)
# Out:
#   Import Country  Transaction Count
# 0             US               2601
# 1             JP               1320
# 2             HK               1047
# 3             CN                815
# 4             FR                744
# 5             CH                716
# 6             IT                628
# 7             KR                593
# 8             SG                509
# 9             DE                488

# %%
TopImporter_df.head(10)
# Out:
#   Import Country  Transaction Count
# 0             US               2601
# 1             JP               1320
# 2             HK               1047
# 3             CN                815
# 4             FR                744
# 5             CH                716
# 6             IT                628
# 7             KR                593
# 8             SG                509
# 9             DE                488

# %%
latlonfile_df.head(1)
# Out:
#   Country  Lattitude  Longitude     Name
# 0      AD  42.546245   1.601554  Andorra

# %%
TopImporter_df["Import Country"]
latlonfile_df["Country"]
TopImporter_df = TopImporter_df.merge(latlonfile_df, left_on='Import Country', right_on='Country', how='inner')
TopImporter_df.head(10)
# Out:
#   Import Country  Transaction Count Country  Lattitude   Longitude  \
# 0             US               2601      US  37.090240  -95.712891
# 1             JP               1320      JP  36.204824  138.252924
# 2             HK               1047      HK  22.396428  114.109497
# 3             CN                815      CN  35.861660  104.195397
# 4             FR                744      FR  46.227638    2.213749
# 5             CH                716      CH  46.818188    8.227512
# 6             IT                628      IT  41.871940   12.567380
# 7             KR                593      KR  35.907757  127.766922
# 8             SG                509      SG   1.352083  103.819836
# 9             DE                488      DE  51.165691   10.451526
#
#             Name
# 0  United States
# 1          Japan
# 2      Hong Kong
# 3          China
# 4         France
# 5    Switzerland
# 6          Italy
# 7    South Korea
# 8      Singapore
# 9        Germany

# %%
TopImporter_croc_df.head()
# Out:
#    Year App.                     Taxon     Class       Order         Family  \
# 3  2016   II         Caiman crocodilus  Reptilia  Crocodylia  Alligatoridae
# 4  2016   II  Caiman crocodilus fuscus  Reptilia  Crocodylia  Alligatoridae
# 5  2016   II      Crocodylus niloticus  Reptilia  Crocodylia   Crocodylidae
# 7  2016   II         Python bivittatus  Reptilia   Serpentes     Pythonidae
# 8  2016   II         Python bivittatus  Reptilia   Serpentes     Pythonidae
#
#         Genus Importer Exporter Origin  Importer reported quantity  \
# 3      Caiman       TR       NL     CO                         1.0
# 4      Caiman       TR       NL     CO                         NaN
# 5  Crocodylus       TR       NL     ZA                         1.0
# 7      Python       TR       NL     VN                        25.0
# 8      Python       TR       NL    NaN                         1.0
#
#    Exporter reported quantity                      Term Unit Purpose Source  \
# 3                         NaN  leather products (small)  NaN       T      C
# 4                         5.0  leather products (small)  NaN       T      C
# 5                         NaN  leather products (small)  NaN       T      C
# 7                        33.0  leather products (small)  NaN       T      C
# 8                         NaN  leather products (small)  NaN       T      C
#
#   Purpose Description                                 Source Description  \
# 3          Commercial  Animals bred in captivity in accordance with R...
# 4          Commercial  Animals bred in captivity in accordance with R...
# 5          Commercial  Animals bred in captivity in accordance with R...
# 7          Commercial  Animals bred in captivity in accordance with R...
# 8          Commercial  Animals bred in captivity in accordance with R...
#
#   Importer Country Name Exporter Country Name
# 3                Turkey           Netherlands
# 4                Turkey           Netherlands
# 5                Turkey           Netherlands
# 7                Turkey           Netherlands
# 8                Turkey           Netherlands

# %%
# Group by Exporting Countries
TopExporter_croc_df = pd.DataFrame(input_df.loc[input_df["Class"]=="Reptilia"])

# Using GroupBy in order to summarize the data by 'Importer Country Name' values
#GrpdByExporterData = TopExporter_croc_df.groupby(['Exporter Country Name'])
GrpdByExporterData = TopExporter_croc_df.groupby(['Exporter'])

# Transaction count
#ExportTransactionCount = TopExporter_croc_df['Exporter Country Name'].value_counts()
ExportTransactionCount = TopExporter_croc_df['Exporter'].value_counts()

# Construct the output table
# In order to be visualized, a data function must be used...
TopExporter_df = pd.DataFrame({'Transaction Count': ExportTransactionCount})
# convert the index into a column
TopExporter_df.sort_values("Transaction Count", inplace=True, ascending=False)
TopExporter_df.reset_index(inplace=True)
TopExporter_df = TopExporter_df.rename(columns = {'index' : 'Export Country'})
TopExporter_df.to_csv(ExporterFile, encoding='utf-8', index=False)
TopExporter_df.head(3)
TopExporter_croc_df.head()
# Out:
#    Year App.                     Taxon     Class       Order         Family  \
# 3  2016   II         Caiman crocodilus  Reptilia  Crocodylia  Alligatoridae
# 4  2016   II  Caiman crocodilus fuscus  Reptilia  Crocodylia  Alligatoridae
# 5  2016   II      Crocodylus niloticus  Reptilia  Crocodylia   Crocodylidae
# 7  2016   II         Python bivittatus  Reptilia   Serpentes     Pythonidae
# 8  2016   II         Python bivittatus  Reptilia   Serpentes     Pythonidae
#
#         Genus Importer Exporter Origin  Importer reported quantity  \
# 3      Caiman       TR       NL     CO                         1.0
# 4      Caiman       TR       NL     CO                         NaN
# 5  Crocodylus       TR       NL     ZA                         1.0
# 7      Python       TR       NL     VN                        25.0
# 8      Python       TR       NL    NaN                         1.0
#
#    Exporter reported quantity                      Term Unit Purpose Source  \
# 3                         NaN  leather products (small)  NaN       T      C
# 4                         5.0  leather products (small)  NaN       T      C
# 5                         NaN  leather products (small)  NaN       T      C
# 7                        33.0  leather products (small)  NaN       T      C
# 8                         NaN  leather products (small)  NaN       T      C
#
#   Purpose Description                                 Source Description  \
# 3          Commercial  Animals bred in captivity in accordance with R...
# 4          Commercial  Animals bred in captivity in accordance with R...
# 5          Commercial  Animals bred in captivity in accordance with R...
# 7          Commercial  Animals bred in captivity in accordance with R...
# 8          Commercial  Animals bred in captivity in accordance with R...
#
#   Importer Country Name Exporter Country Name
# 3                Turkey           Netherlands
# 4                Turkey           Netherlands
# 5                Turkey           Netherlands
# 7                Turkey           Netherlands
# 8                Turkey           Netherlands

# %%
#TopExporter_df.head(10)
#TopExporter_df["Export Country"]
#latlonfile_df["Country"]
TopExporter_df = TopExporter_df.merge(latlonfile_df, left_on='Export Country', right_on='Country', how='inner')
TopExporter_df.head(10)
# Out:
#   Export Country  Transaction Count Country  Lattitude   Longitude  \
# 0             IT               3961      IT  41.871940   12.567380
# 1             FR               2026      FR  46.227638    2.213749
# 2             US               1143      US  37.090240  -95.712891
# 3             CH                884      CH  46.818188    8.227512
# 4             SG                880      SG   1.352083  103.819836
# 5             DE                840      DE  51.165691   10.451526
# 6             ID                824      ID  -0.789275  113.921327
# 7             HK                616      HK  22.396428  114.109497
# 8             GB                497      GB  55.378051   -3.435973
# 9             ES                445      ES  40.463667   -3.749220
#
#              Name
# 0           Italy
# 1          France
# 2   United States
# 3     Switzerland
# 4       Singapore
# 5         Germany
# 6       Indonesia
# 7       Hong Kong
# 8  United Kingdom
# 9           Spain

# %%
TopImporter_croc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17910 entries, 3 to 60626
# Data columns (total 20 columns):
# Year                          17910 non-null int64
# App.                          17910 non-null object
# Taxon                         17910 non-null object
# Class                         17910 non-null object
# Order                         17906 non-null object
# Family                        17883 non-null object
# Genus                         17754 non-null object
# Importer                      17898 non-null object
# Exporter                      17885 non-null object
# Origin                        13866 non-null object
# Importer reported quantity    8439 non-null float64
# Exporter reported quantity    12754 non-null float64
# Term                          17910 non-null object
# Unit                          212 non-null object
# Purpose                       17910 non-null object
# Source                        17910 non-null object
# Purpose Description           17910 non-null object
# Source Description            17910 non-null object
# Importer Country Name         17910 non-null object
# Exporter Country Name         17910 non-null object
# dtypes: float64(2), int64(1), object(17)
# memory usage: 2.9+ MB

# %%
# Top Importer by Importer reported quantities

# Using GroupBy in order to summarize the data by 'Importer Country Name' values
GrpdByImpQtyData = TopExporter_croc_df.groupby(['Importer Country Name'])

# Transaction count
ImportTransCount = TopExporter_croc_df['Importer Country Name'].value_counts()
ImportRptdQuantity = GrpdByImpQtyData['Importer reported quantity'].sum()
# Construct the output table
# In order to be visualized, a data function must be used...
TopImpQty_df = pd.DataFrame({'Transaction Count': ImportTransCount,
                            'Quantity Imported': ImportRptdQuantity })

# sort and convert the index into a column
TopImpQty_df.sort_values("Quantity Imported", inplace=True, ascending=False)
TopImpQty_df.reset_index(inplace=True)
TopImpQty_df = TopImpQty_df.rename(columns = {'index' : 'Import Country'})
TopImpQty_df.to_csv(ImpQtyFile, encoding='utf-8', index=False)
TopImpQty_df.head(3)
# Out:
#              Import Country  Quantity Imported  Transaction Count
# 0      Hong Kong, SAR China         2017551.93               1047
# 1  United States of America         1382983.59               2601
# 2                    France         1118549.31                744

# %%
# Top Importer by Exporter reported quantities

# Using GroupBy in order to summarize the data by 'Importer Country Name' values
GrpdByExpQtyData = TopExporter_croc_df.groupby(['Exporter Country Name'])

# Transaction count
ExportTransCount = TopExporter_croc_df['Exporter Country Name'].value_counts()
ExportRptdQuantity = GrpdByExpQtyData['Exporter reported quantity'].sum()
# Construct the output table
# In order to be visualized, a data function must be used...
TopExpQty_df = pd.DataFrame({'Transaction Count': ExportTransCount,
                            'Quantity Exported': ExportRptdQuantity })

# convert the index into a column
TopExpQty_df.sort_values("Quantity Exported", inplace=True, ascending=False)
TopExpQty_df.reset_index(inplace=True)
TopExpQty_df = TopExpQty_df.rename(columns = {'index' : 'Export Country'})
TopExpQty_df.to_csv(ExpQtyFile, encoding='utf-8', index=False)
TopExpQty_df.head(3)
# Out:
#              Export Country  Quantity Exported  Transaction Count
# 0                    France       1.616457e+06               2026
# 1  United States of America       1.390884e+06               1143
# 2                     Italy       1.208306e+06               3961

# %%
TopTenExporter_df = pd.DataFrame(TopExporter_df["Transaction Count"].nlargest(10))
TopTenExporter_df.head()
TopTenExporter_df

TopTenExporter_df = TopTenExporter_df.merge(TopExporter_df, left_on='Transaction Count', right_on='Transaction Count', how='left')
TopTenExporter_df.head(10)
# Out:
#    Transaction Count Export Country Country  Lattitude   Longitude  \
# 0               3961             IT      IT  41.871940   12.567380
# 1               2026             FR      FR  46.227638    2.213749
# 2               1143             US      US  37.090240  -95.712891
# 3                884             CH      CH  46.818188    8.227512
# 4                880             SG      SG   1.352083  103.819836
# 5                840             DE      DE  51.165691   10.451526
# 6                824             ID      ID  -0.789275  113.921327
# 7                616             HK      HK  22.396428  114.109497
# 8                497             GB      GB  55.378051   -3.435973
# 9                445             ES      ES  40.463667   -3.749220
#
#              Name
# 0           Italy
# 1          France
# 2   United States
# 3     Switzerland
# 4       Singapore
# 5         Germany
# 6       Indonesia
# 7       Hong Kong
# 8  United Kingdom
# 9           Spain

# %%
TopTenImporter_df = pd.DataFrame(TopImporter_df["Transaction Count"].nlargest(10))
TopTenImporter_df.head()
TopTenImporter_df

TopTenImporter_df = TopTenImporter_df.merge(TopImporter_df, left_on='Transaction Count', right_on='Transaction Count', how='left')
print(TopTenImporter_df.head(10))
TopTenExporter_df.head(10)
# Out:
#    Transaction Count Import Country Country  Lattitude   Longitude  \
# 0               2601             US      US  37.090240  -95.712891
# 1               1320             JP      JP  36.204824  138.252924
# 2               1047             HK      HK  22.396428  114.109497
# 3                815             CN      CN  35.861660  104.195397
# 4                744             FR      FR  46.227638    2.213749
# 5                716             CH      CH  46.818188    8.227512
# 6                628             IT      IT  41.871940   12.567380
# 7                593             KR      KR  35.907757  127.766922
# 8                509             SG      SG   1.352083  103.819836
# 9                488             DE      DE  51.165691   10.451526
#
#             Name
# 0  United States
# 1          Japan
# 2      Hong Kong
# 3          China
# 4         France
# 5    Switzerland
# 6          Italy
# 7    South Korea
# 8      Singapore
# 9        Germany
#    Transaction Count Export Country Country  Lattitude   Longitude  \
# 0               3961             IT      IT  41.871940   12.567380
# 1               2026             FR      FR  46.227638    2.213749
# 2               1143             US      US  37.090240  -95.712891
# 3                884             CH      CH  46.818188    8.227512
# 4                880             SG      SG   1.352083  103.819836
# 5                840             DE      DE  51.165691   10.451526
# 6                824             ID      ID  -0.789275  113.921327
# 7                616             HK      HK  22.396428  114.109497
# 8                497             GB      GB  55.378051   -3.435973
# 9                445             ES      ES  40.463667   -3.749220
#
#              Name
# 0           Italy
# 1          France
# 2   United States
# 3     Switzerland
# 4       Singapore
# 5         Germany
# 6       Indonesia
# 7       Hong Kong
# 8  United Kingdom
# 9           Spain

# %%
#Rename the coordenates list for TopExporters
### populate latitude and longitude using coordinates from the Country 
latitude = TopTenExporter_df["Lattitude"]
longitude = TopTenExporter_df["Longitude"]

# %%
#Generate city names for the lat and long coordenates above
city_names = []
for x in range(0,len(TopTenExporter_df)):
    city_name = citipy.nearest_city(latitude[x],longitude[x])
    city_names.append(city_name)
#city_names

#Generate the city and country lists 
city_list = []
for x in range(0,len(TopTenExporter_df)):
    city = city_names[x].city_name
    #print(city_names[x].city_name)
    city_list.append(city)

country_list = []
for y in range(0,len(TopTenExporter_df)):
    country = city_names[y].country_code
    #print(city_names[y].country_code)
    country_list.append(country)

#Generate Dataframe
location_df = pd.DataFrame()

location_df["Latitude"] = ""
location_df["Longitude"] = ""
location_df['City'] = ''
location_df['Country Code'] = ''
location_df = location_df.append(pd.DataFrame.from_dict({"Latitude":latitude,"Longitude":longitude,"City":city_list,"Country Code":country_list,}))
location_df = location_df.reset_index(drop=True)
location_df.shape
#location_df

#Clean the data, drop the duplicated citites and reindex
drop_location_df = location_df.drop_duplicates(['City'])
drop_location_df.shape
new_location_df = drop_location_df#.sample(sample)
city_coordinates_df = new_location_df.reset_index(drop=True)

#See the random coordenates in the map for the nearest cities:
#import cartopy.crs as ccrs

#fig, ax = plt.subplots(figsize = (20,10))

#ax = plt.axes(projection=ccrs.PlateCarree())
#ax.stock_img()

#plt.scatter(list(city_coordinates_df['Longitude']),list(city_coordinates_df['Latitude']), color='red', marker = 'x', transform = ccrs.Geodetic(),)

#plt.title('Distribution of Countries')
#plt.savefig('DistributionOfCountries')
#plt.show()

# %%
#print(TopTenImporter_df.head())
#Rename the coordenates list for TopExporters
### populate latitude and longitude using coordinates from the Country 
import_latitude = TopTenImporter_df["Lattitude"]
import_longitude = TopTenImporter_df["Longitude"]
print(TopTenImporter_df.head())
# Out:
#    Transaction Count Import Country Country  Lattitude   Longitude  \
# 0               2601             US      US  37.090240  -95.712891
# 1               1320             JP      JP  36.204824  138.252924
# 2               1047             HK      HK  22.396428  114.109497
# 3                815             CN      CN  35.861660  104.195397
# 4                744             FR      FR  46.227638    2.213749
#
#             Name
# 0  United States
# 1          Japan
# 2      Hong Kong
# 3          China
# 4         France

# %%
#### Origin #####

#print(TopImporter_croc_df.head())
# Group by Importing country
# Using GroupBy in order to summarize the data by 'Importer Country Name' values
#GrpdByImporterData = input_df.groupby(['Importer Country Name'])
#GrpdByImporterData = TopImporter_croc_df.groupby(['Importer Country Name'])
#GrpdByImporterData = TopImporter_croc_df.groupby(['Importer'])
GrpdByOriginData = TopImporter_croc_df.groupby(['Origin'])

# Transaction count
#ImportTransactionCount = TopImporter_croc_df['Importer Country Name'].value_counts()

# Transaction count
OriginTransactionCount = TopImporter_croc_df['Origin'].value_counts()


# Construct the output table
# In order to be visualized, a data function must be used...
TopOrigin_df = pd.DataFrame({'Transaction Count': OriginTransactionCount})
# convert the index into a column
TopOrigin_df.sort_values("Transaction Count", inplace=True, ascending=False)
TopOrigin_df.reset_index(inplace=True)
TopOrigin_df = TopOrigin_df.rename(columns = {'index' : 'Origin Country'})
TopOrigin_df.to_csv(OriginFile, encoding='utf-8', index=False)
TopOrigin_df.head(10)
# Out:
#   Origin Country  Transaction Count
# 0             ID               2203
# 1             US               1875
# 2             VN               1511
# 3             ZW               1088
# 4             AU                610
# 5             CO                597
# 6             XX                563
# 7             LA                500
# 8             BO                495
# 9             ZA                487

# %%
TopOrigin_df["Origin Country"]
latlonfile_df["Country"]
TopOrigin_df = TopOrigin_df.merge(latlonfile_df, left_on='Origin Country', right_on='Country', how='inner')
TopOrigin_df.head(10)

TopTenOrigin_df = pd.DataFrame(TopOrigin_df["Transaction Count"].nlargest(10))
TopTenOrigin_df.head()
TopTenOrigin_df

TopTenOrigin_df = TopTenOrigin_df.merge(TopOrigin_df, left_on='Transaction Count', right_on='Transaction Count', how='left')
print(TopTenOrigin_df.head(10))
TopTenOrigin_df.head(10)
# Out:
#    Transaction Count Origin Country Country  Lattitude   Longitude  \
# 0               2203             ID      ID  -0.789275  113.921327
# 1               1875             US      US  37.090240  -95.712891
# 2               1511             VN      VN  14.058324  108.277199
# 3               1088             ZW      ZW -19.015438   29.154857
# 4                610             AU      AU -25.274398  133.775136
# 5                597             CO      CO   4.570868  -74.297333
# 6                500             LA      LA  19.856270  102.495496
# 7                495             BO      BO -16.290154  -63.588653
# 8                487             ZA      ZA -30.559482   22.937506
# 9                483             MY      MY   4.210484  101.975766
#
#             Name
# 0      Indonesia
# 1  United States
# 2        Vietnam
# 3       Zimbabwe
# 4      Australia
# 5       Colombia
# 6           Laos
# 7        Bolivia
# 8   South Africa
# 9       Malaysia
#    Transaction Count Origin Country Country  Lattitude   Longitude  \
# 0               2203             ID      ID  -0.789275  113.921327
# 1               1875             US      US  37.090240  -95.712891
# 2               1511             VN      VN  14.058324  108.277199
# 3               1088             ZW      ZW -19.015438   29.154857
# 4                610             AU      AU -25.274398  133.775136
# 5                597             CO      CO   4.570868  -74.297333
# 6                500             LA      LA  19.856270  102.495496
# 7                495             BO      BO -16.290154  -63.588653
# 8                487             ZA      ZA -30.559482   22.937506
# 9                483             MY      MY   4.210484  101.975766
#
#             Name
# 0      Indonesia
# 1  United States
# 2        Vietnam
# 3       Zimbabwe
# 4      Australia
# 5       Colombia
# 6           Laos
# 7        Bolivia
# 8   South Africa
# 9       Malaysia

# %%
#Rename the coordenates list for TopExporters
### populate latitude and longitude using coordinates from the Country 
origin_latitude = TopTenOrigin_df["Lattitude"]
origin_longitude = TopTenOrigin_df["Longitude"]

# %%
#Generate city names for the lat and long coordenates above
origin_city_names = []
for x in range(0,len(TopTenOrigin_df)):
    origin_city_name = citipy.nearest_city(origin_latitude[x],origin_longitude[x])
    origin_city_names.append(origin_city_name)
    #print(origin_latitude[x])
#city_names
print(origin_city_names)   
    
#Generate the city and country lists 
origin_city_list = []
for x in range(0,len(TopTenOrigin_df)):
    origin_city = origin_city_names[x].city_name
    #print(import_city_names[x].city_name)
    origin_city_list.append(origin_city)
#print(import_city_list)

origin_country_list = []
for y in range(0,len(TopTenOrigin_df)):
    origin_country = origin_city_names[y].country_code
    #print(city_names[y].country_code)
    origin_country_list.append(origin_country)
#print(import_country_list)



print(TopTenOrigin_df)

#Generate Dataframe
origin_location_df = pd.DataFrame()

origin_location_df["Latitude"] = ""
origin_location_df["Longitude"] = ""
origin_location_df['City'] = ''
origin_location_df['Country Code'] = ''
origin_location_df = origin_location_df.append(pd.DataFrame.from_dict({"Latitude":origin_latitude,"Longitude":origin_longitude,"City":origin_city_list,"Country Code":origin_country_list,}))
origin_location_df = origin_location_df.reset_index(drop=True)
origin_location_df.shape
#location_df
#print(import_location_df.head())

#Clean the data, drop the duplicated citites and reindex
origin_drop_location_df = origin_location_df.drop_duplicates(['City'])
origin_drop_location_df.shape
origin_new_location_df = origin_drop_location_df#.sample(sample)
origin_city_coordinates_df = origin_new_location_df.reset_index(drop=True)

#print(len(origin_city_coordinates_df))

print(origin_city_coordinates_df['Longitude'])

#See the random coordenates in the map for the nearest cities:
#import cartopy.crs as ccrs

#fig, ax = plt.subplots(figsize = (20,10))

#ax = plt.axes(projection=ccrs.PlateCarree())
#ax.stock_img()
#origin = plt.scatter(list(origin_city_coordinates_df['Longitude']),list(origin_city_coordinates_df['Latitude']), color='green', marker = '*', label = "Origin", transform = ccrs.Geodetic(),)

#plt.scatter(list(city_coordinates_df['Longitude']),list(city_coordinates_df['Latitude']), color='red', marker = 'x', transform = ccrs.Geodetic(),)

#plt.title('Distribution of Countries')
#plt.savefig('DistributionOfCountries')
#plt.show()
# Out:
# [<citipy.citipy.City object at 0x0000018D132C7C88>, <citipy.citipy.City object at 0x0000018D143F3940>, <citipy.citipy.City object at 0x0000018D146F6550>, <citipy.citipy.City object at 0x0000018D14731128>, <citipy.citipy.City object at 0x0000018D12996940>, <citipy.citipy.City object at 0x0000018D12D670F0>, <citipy.citipy.City object at 0x0000018D13777748>, <citipy.citipy.City object at 0x0000018D12A64630>, <citipy.citipy.City object at 0x0000018D14708B00>, <citipy.citipy.City object at 0x0000018D13919128>]
#    Transaction Count Origin Country Country  Lattitude   Longitude  \
# 0               2203             ID      ID  -0.789275  113.921327
# 1               1875             US      US  37.090240  -95.712891
# 2               1511             VN      VN  14.058324  108.277199
# 3               1088             ZW      ZW -19.015438   29.154857
# 4                610             AU      AU -25.274398  133.775136
# 5                597             CO      CO   4.570868  -74.297333
# 6                500             LA      LA  19.856270  102.495496
# 7                495             BO      BO -16.290154  -63.588653
# 8                487             ZA      ZA -30.559482   22.937506
# 9                483             MY      MY   4.210484  101.975766
#
#             Name
# 0      Indonesia
# 1  United States
# 2        Vietnam
# 3       Zimbabwe
# 4      Australia
# 5       Colombia
# 6           Laos
# 7        Bolivia
# 8   South Africa
# 9       Malaysia
# 0    113.921327
# 1    -95.712891
# 2    108.277199
# 3     29.154857
# 4    133.775136
# 5    -74.297333
# 6    102.495496
# 7    -63.588653
# 8     22.937506
# 9    101.975766
# Name: Longitude, dtype: float64

# %%
#Generate city names for the lat and long coordenates above
import_city_names = []
for x in range(0,len(TopTenImporter_df)):
    import_city_name = citipy.nearest_city(import_latitude[x],import_longitude[x])
    import_city_names.append(import_city_name)
    #print(import_latitude[x])
#city_names
#print(import_city_names)   
    
#Generate the city and country lists 
import_city_list = []
for x in range(0,len(TopTenImporter_df)):
    import_city = import_city_names[x].city_name
    #print(import_city_names[x].city_name)
    import_city_list.append(import_city)
#print(import_city_list)

import_country_list = []
for y in range(0,len(TopTenImporter_df)):
    import_country = import_city_names[y].country_code
    #print(city_names[y].country_code)
    import_country_list.append(import_country)
#print(import_country_list)

#Generate Dataframe
import_location_df = pd.DataFrame()

import_location_df["Latitude"] = ""
import_location_df["Longitude"] = ""
import_location_df['City'] = ''
import_location_df['Country Code'] = ''
import_location_df = import_location_df.append(pd.DataFrame.from_dict({"Latitude":import_latitude,"Longitude":import_longitude,"City":import_city_list,"Country Code":import_country_list,}))
import_location_df = import_location_df.reset_index(drop=True)
import_location_df.shape
#location_df
#print(import_location_df.head())

#Clean the data, drop the duplicated citites and reindex
import_drop_location_df = import_location_df.drop_duplicates(['City'])
import_drop_location_df.shape
import_new_location_df = import_drop_location_df#.sample(sample)
import_city_coordinates_df = import_new_location_df.reset_index(drop=True)

#print(import_city_coordinates_df.head(10))
#See the random coordenates in the map for the nearest cities:
import cartopy.crs as ccrs

fig, ax = plt.subplots(figsize = (20,10))

ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img()

origin = plt.scatter(list(origin_city_coordinates_df['Longitude']),list(origin_city_coordinates_df['Latitude']), s=80, color='black', marker = '*', label = "Origin", transform = ccrs.Geodetic(),)
exporters = plt.scatter(list(city_coordinates_df['Longitude']),list(city_coordinates_df['Latitude']), color='red', marker = 'x', label = "Exporters", transform = ccrs.Geodetic(),)
importers = plt.scatter(list(import_city_coordinates_df['Longitude']),list(import_city_coordinates_df['Latitude']),s=150,facecolors='none', edgecolors = 'blue', marker = 'o', label = "Importers", transform = ccrs.Geodetic(),)

#lt.scatter(x, y, s=80, facecolors='none', edgecolors='r')

plt.title('Top 10 Countries that Import, Export and Originate Reptilia',fontsize=35)
# Put a legend to the right of the current axis

ax.legend(handles=[exporters,importers,origin], title = "Import/Export",fontsize=20, loc='center left', bbox_to_anchor=(1, 0.5))

plt.savefig('Top10ImportExportOriginCountries')
plt.show()
